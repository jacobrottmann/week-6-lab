# %%
name = input("What is your name?")
age = input("How old are you?")
print("Your name is "+name+" and you are "+age+" years old.")
# Out:
# What is your name? Jacob
# How old are you? 18
# Your name is Jacob and you are 18 years old.
